# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'   # sharper images on retina screens

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Use very safe, default style to avoid backend/style problems
plt.style.use('default')
sns.set_theme(style="whitegrid", palette="muted")

print("Setup complete – ready to go")
